# %% [markdown]
# Thanks to https://www.kaggle.com/xhlulu/ranzcr-efficientnet-tpu-training

# %%
# !pip install efficientnet -q
# Out:
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv

# %%
import os

import efficientnet.tfkeras as efn
import numpy as np
import pandas as pd
from kaggle_datasets import KaggleDatasets
from sklearn.model_selection import train_test_split
import tensorflow as tf
from sklearn.model_selection import GroupKFold

# %%
def auto_select_accelerator():
    try:
        tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
        tf.config.experimental_connect_to_cluster(tpu)
        tf.tpu.experimental.initialize_tpu_system(tpu)
        strategy = tf.distribute.experimental.TPUStrategy(tpu)
        print("Running on TPU:", tpu.master())
    except ValueError:
        strategy = tf.distribute.get_strategy()
    print(f"Running on {strategy.num_replicas_in_sync} replicas")
    
    return strategy


def build_decoder(with_labels=True, target_size=(256, 256), ext='jpg'):
    def decode(path):
        file_bytes = tf.io.read_file(path)

        if ext == 'png':
            img = tf.image.decode_png(file_bytes, channels=3)
        elif ext in ['jpg', 'jpeg']:
            img = tf.image.decode_jpeg(file_bytes, channels=3)
        else:
            raise ValueError("Image extension not supported")
        img = tf.cast(img, tf.float32) / 255.0
        img = tf.image.resize(img, target_size)

        return img
    
    def decode_with_labels(path, label):
        return decode(path), label
    
    return decode_with_labels if with_labels else decode


def build_augmenter(with_labels=True):
    def augment(img):
        img = tf.image.random_flip_left_right(img)
        img = tf.image.random_flip_up_down(img)
        return img
    
    def augment_with_labels(img, label):
        return augment(img), label
    
    return augment_with_labels if with_labels else augment


def build_dataset(paths, labels=None, bsize=128, cache=True,
                  decode_fn=None, augment_fn=None,
                  augment=True, repeat=True, shuffle=1024, 
                  cache_dir=""):
    if cache_dir != "" and cache is True:
        os.makedirs(cache_dir, exist_ok=True)
    
    if decode_fn is None:
        decode_fn = build_decoder(labels is not None)
    
    if augment_fn is None:
        augment_fn = build_augmenter(labels is not None)
    
    AUTO = tf.data.experimental.AUTOTUNE
    slices = paths if labels is None else (paths, labels)
    
    dset = tf.data.Dataset.from_tensor_slices(slices)
    dset = dset.map(decode_fn, num_parallel_calls=AUTO)
    dset = dset.cache(cache_dir) if cache else dset
    dset = dset.map(augment_fn, num_parallel_calls=AUTO) if augment else dset
    dset = dset.repeat() if repeat else dset
    dset = dset.shuffle(shuffle) if shuffle else dset
    dset = dset.batch(bsize).prefetch(AUTO)
    
    return dset

# %%
COMPETITION_NAME = "siimcovid19-512-img-png-600-study-png"
strategy = auto_select_accelerator()
BATCH_SIZE = strategy.num_replicas_in_sync * 16
GCS_DS_PATH = KaggleDatasets().get_gcs_path(COMPETITION_NAME)
# Out:
# Running on TPU: grpc://10.0.0.2:8470
# Running on 8 replicas

# %%
load_dir = f"/kaggle/input/{COMPETITION_NAME}/"
df = pd.read_csv('../input/siim-covid19-detection/train_study_level.csv')
label_cols = df.columns[1:5]

# %%
gkf  = GroupKFold(n_splits = 5)
df['fold'] = -1
for fold, (train_idx, val_idx) in enumerate(gkf.split(df, groups = df.id.tolist())):
    df.loc[val_idx, 'fold'] = fold

# %%
for i in range(5):
    
    valid_paths = GCS_DS_PATH + '/study/' + df[df['fold'] == i]['id'] + '.png' #"/train/"
    train_paths = GCS_DS_PATH + '/study/' + df[df['fold'] != i]['id'] + '.png' #"/train/" 
    valid_labels = df[df['fold'] == i][label_cols].values
    train_labels = df[df['fold'] != i][label_cols].values

    IMSIZE = (224, 240, 260, 300, 380, 456, 528, 600)
    IMS = 7

    decoder = build_decoder(with_labels=True, target_size=(IMSIZE[IMS], IMSIZE[IMS]), ext='png')
    test_decoder = build_decoder(with_labels=False, target_size=(IMSIZE[IMS], IMSIZE[IMS]),ext='png')

    train_dataset = build_dataset(
        train_paths, train_labels, bsize=BATCH_SIZE, decode_fn=decoder
    )

    valid_dataset = build_dataset(
        valid_paths, valid_labels, bsize=BATCH_SIZE, decode_fn=decoder,
        repeat=False, shuffle=False, augment=False
    )

    try:
        n_labels = train_labels.shape[1]
    except:
        n_labels = 1

    with strategy.scope():
        model = tf.keras.Sequential([
            efn.EfficientNetB5(
                input_shape=(IMSIZE[IMS], IMSIZE[IMS], 3),
                weights='imagenet',
                include_top=False),
            tf.keras.layers.GlobalAveragePooling2D(),
            tf.keras.layers.Dense(n_labels, activation='softmax')
        ])
        model.compile(
            optimizer=tf.keras.optimizers.Adam(),
            loss='categorical_crossentropy',
            metrics=[tf.keras.metrics.AUC(multi_label=True)])

        model.summary()


    steps_per_epoch = train_paths.shape[0] // BATCH_SIZE
    checkpoint = tf.keras.callbacks.ModelCheckpoint(
        f'model{i}.h5', save_best_only=True, monitor='val_loss', mode='min')
    lr_reducer = tf.keras.callbacks.ReduceLROnPlateau(
        monitor="val_loss", patience=3, min_lr=1e-6, mode='min')

    history = model.fit(
        train_dataset, 
        epochs=20,
        verbose=1,
        callbacks=[checkpoint, lr_reducer],
        steps_per_epoch=steps_per_epoch,
        validation_data=valid_dataset)

    hist_df = pd.DataFrame(history.history)
    hist_df.to_csv(f'history{i}.csv')
# Out:
# Downloading data from https://github.com/Callidior/keras-applications/releases/download/efficientnet/efficientnet-b5_weights_tf_dim_ordering_tf_kernels_autoaugment_notop.h5
# 115515392/115515256 [==============================] - 3s 0us/step
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# efficientnet-b5 (Functional) (None, 19, 19, 2048)      28513520
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 4)                 8196
# =================================================================
# Total params: 28,521,716
# Trainable params: 28,348,980
# Non-trainable params: 172,736
# _________________________________________________________________
# Epoch 1/20
# 37/37 [==============================] - 315s 4s/step - loss: 1.1557 - auc: 0.6404 - val_loss: 1.0922 - val_auc: 0.7199
# Epoch 2/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.9346 - auc: 0.7562 - val_loss: 0.9739 - val_auc: 0.7486
# Epoch 3/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.9235 - auc: 0.7776 - val_loss: 0.9449 - val_auc: 0.7682
# Epoch 4/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.8894 - auc: 0.7867 - val_loss: 1.0210 - val_auc: 0.7455
# Epoch 5/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.8443 - auc: 0.8159 - val_loss: 1.1323 - val_auc: 0.7698
# Epoch 6/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.8122 - auc: 0.8276 - val_loss: 1.2016 - val_auc: 0.7510
# Epoch 7/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.7778 - auc: 0.8499 - val_loss: 1.0384 - val_auc: 0.7768
# Epoch 8/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.6603 - auc: 0.8930 - val_loss: 1.0065 - val_auc: 0.7710
# Epoch 9/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.6301 - auc: 0.9026 - val_loss: 1.0074 - val_auc: 0.7738
# Epoch 10/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.6190 - auc: 0.9079 - val_loss: 0.9689 - val_auc: 0.7795
# Epoch 11/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.6079 - auc: 0.9143 - val_loss: 0.9641 - val_auc: 0.7824
# Epoch 12/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.5864 - auc: 0.9180 - val_loss: 0.9679 - val_auc: 0.7828
# Epoch 13/20
# 37/37 [==============================] - 40s 1s/step - loss: 0.5780 - auc: 0.9220 - val_loss: 0.9706 - val_auc: 0.7827
# Epoch 14/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.6018 - auc: 0.9132 - val_loss: 0.9730 - val_auc: 0.7838
# Epoch 15/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.5784 - auc: 0.9214 - val_loss: 0.9740 - val_auc: 0.7855
# Epoch 16/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.5836 - auc: 0.9162 - val_loss: 0.9755 - val_auc: 0.7869
# Epoch 17/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.5869 - auc: 0.9187 - val_loss: 0.9769 - val_auc: 0.7883
# Epoch 18/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.5988 - auc: 0.9131 - val_loss: 0.9810 - val_auc: 0.7887
# Epoch 19/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.5710 - auc: 0.9233 - val_loss: 0.9852 - val_auc: 0.7891
# Epoch 20/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.5861 - auc: 0.9168 - val_loss: 0.9868 - val_auc: 0.7898
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# efficientnet-b5 (Functional) (None, 19, 19, 2048)      28513520
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 2048)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 4)                 8196
# =================================================================
# Total params: 28,521,716
# Trainable params: 28,348,980
# Non-trainable params: 172,736
# _________________________________________________________________
# Epoch 1/20
# 37/37 [==============================] - 262s 3s/step - loss: 1.1250 - auc_1: 0.6474 - val_loss: 1.2300 - val_auc_1: 0.7337
# Epoch 2/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.9534 - auc_1: 0.7453 - val_loss: 1.3692 - val_auc_1: 0.7409
# Epoch 3/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.9121 - auc_1: 0.7770 - val_loss: 1.4498 - val_auc_1: 0.7236
# Epoch 4/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.8751 - auc_1: 0.7958 - val_loss: 1.1072 - val_auc_1: 0.7736
# Epoch 5/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.8184 - auc_1: 0.8222 - val_loss: 1.1431 - val_auc_1: 0.7669
# Epoch 6/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.8122 - auc_1: 0.8221 - val_loss: 1.3385 - val_auc_1: 0.7270
# Epoch 7/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.7401 - auc_1: 0.8580 - val_loss: 1.6418 - val_auc_1: 0.7269
# Epoch 8/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.7043 - auc_1: 0.8736 - val_loss: 1.2176 - val_auc_1: 0.7629
# Epoch 9/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.6254 - auc_1: 0.8991 - val_loss: 1.2036 - val_auc_1: 0.7703
# Epoch 10/20
# 37/37 [==============================] - 40s 1s/step - loss: 0.5761 - auc_1: 0.9183 - val_loss: 1.1456 - val_auc_1: 0.7772
# Epoch 11/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.5307 - auc_1: 0.9304 - val_loss: 1.1177 - val_auc_1: 0.7778
# Epoch 12/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.5341 - auc_1: 0.9265 - val_loss: 1.1069 - val_auc_1: 0.7800
# Epoch 13/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.5312 - auc_1: 0.9262 - val_loss: 1.1068 - val_auc_1: 0.7797
# Epoch 14/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.5401 - auc_1: 0.9247 - val_loss: 1.1020 - val_auc_1: 0.7805
# Epoch 15/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.5084 - auc_1: 0.9358 - val_loss: 1.1101 - val_auc_1: 0.7793
# Epoch 16/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.5069 - auc_1: 0.9384 - val_loss: 1.1200 - val_auc_1: 0.7794
# Epoch 17/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.5096 - auc_1: 0.9368 - val_loss: 1.1328 - val_auc_1: 0.7772
# Epoch 18/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.5235 - auc_1: 0.9316 - val_loss: 1.1346 - val_auc_1: 0.7787
# Epoch 19/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.4976 - auc_1: 0.9398 - val_loss: 1.1376 - val_auc_1: 0.7782
# Epoch 20/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.5198 - auc_1: 0.9372 - val_loss: 1.1401 - val_auc_1: 0.7785
# Model: "sequential_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# efficientnet-b5 (Functional) (None, 19, 19, 2048)      28513520
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 2048)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 4)                 8196
# =================================================================
# Total params: 28,521,716
# Trainable params: 28,348,980
# Non-trainable params: 172,736
# _________________________________________________________________
# Epoch 1/20
# 37/37 [==============================] - 275s 3s/step - loss: 1.1428 - auc_2: 0.6441 - val_loss: 0.9685 - val_auc_2: 0.7493
# Epoch 2/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.9567 - auc_2: 0.7467 - val_loss: 1.0378 - val_auc_2: 0.7676
# Epoch 3/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.9310 - auc_2: 0.7674 - val_loss: 1.0545 - val_auc_2: 0.7689
# Epoch 4/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.9059 - auc_2: 0.7905 - val_loss: 0.9791 - val_auc_2: 0.7834
# Epoch 5/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.8465 - auc_2: 0.8177 - val_loss: 0.9024 - val_auc_2: 0.7934
# Epoch 6/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.7808 - auc_2: 0.8486 - val_loss: 0.8937 - val_auc_2: 0.7964
# Epoch 7/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.7436 - auc_2: 0.8635 - val_loss: 0.9137 - val_auc_2: 0.7954
# Epoch 8/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.7431 - auc_2: 0.8630 - val_loss: 0.8982 - val_auc_2: 0.7898
# Epoch 9/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.6852 - auc_2: 0.8834 - val_loss: 0.9071 - val_auc_2: 0.7912
# Epoch 10/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.6851 - auc_2: 0.8853 - val_loss: 0.9016 - val_auc_2: 0.7931
# Epoch 11/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.6497 - auc_2: 0.8963 - val_loss: 0.9001 - val_auc_2: 0.7959
# Epoch 12/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.6716 - auc_2: 0.8870 - val_loss: 0.8995 - val_auc_2: 0.7968
# Epoch 13/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.6554 - auc_2: 0.8941 - val_loss: 0.8968 - val_auc_2: 0.7979
# Epoch 14/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.6512 - auc_2: 0.9016 - val_loss: 0.8946 - val_auc_2: 0.7993
# Epoch 15/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.6516 - auc_2: 0.8939 - val_loss: 0.8936 - val_auc_2: 0.7987
# Epoch 16/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.6430 - auc_2: 0.8965 - val_loss: 0.8921 - val_auc_2: 0.8010
# Epoch 17/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.6669 - auc_2: 0.8946 - val_loss: 0.8926 - val_auc_2: 0.8015
# Epoch 18/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.6404 - auc_2: 0.9014 - val_loss: 0.8947 - val_auc_2: 0.8015
# Epoch 19/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.6497 - auc_2: 0.8961 - val_loss: 0.8963 - val_auc_2: 0.8023
# Epoch 20/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.6360 - auc_2: 0.8989 - val_loss: 0.8984 - val_auc_2: 0.8034
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# efficientnet-b5 (Functional) (None, 19, 19, 2048)      28513520
# _________________________________________________________________
# global_average_pooling2d_3 ( (None, 2048)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 4)                 8196
# =================================================================
# Total params: 28,521,716
# Trainable params: 28,348,980
# Non-trainable params: 172,736
# _________________________________________________________________
# Epoch 1/20
# 37/37 [==============================] - 267s 3s/step - loss: 1.1422 - auc_3: 0.6449 - val_loss: 1.0230 - val_auc_3: 0.7223
# Epoch 2/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.9717 - auc_3: 0.7401 - val_loss: 1.0811 - val_auc_3: 0.7236
# Epoch 3/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.9038 - auc_3: 0.7799 - val_loss: 1.2073 - val_auc_3: 0.7687
# Epoch 4/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.8934 - auc_3: 0.7909 - val_loss: 0.9779 - val_auc_3: 0.7874
# Epoch 5/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.8459 - auc_3: 0.8098 - val_loss: 0.9436 - val_auc_3: 0.7684
# Epoch 6/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.8357 - auc_3: 0.8276 - val_loss: 0.9908 - val_auc_3: 0.7764
# Epoch 7/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.7739 - auc_3: 0.8474 - val_loss: 1.0247 - val_auc_3: 0.7557
# Epoch 8/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.7512 - auc_3: 0.8592 - val_loss: 1.1870 - val_auc_3: 0.7574
# Epoch 9/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.7157 - auc_3: 0.8782 - val_loss: 0.9888 - val_auc_3: 0.7929
# Epoch 10/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.6016 - auc_3: 0.9081 - val_loss: 1.0042 - val_auc_3: 0.7927
# Epoch 11/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.5492 - auc_3: 0.9250 - val_loss: 1.0352 - val_auc_3: 0.7868
# Epoch 12/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.5125 - auc_3: 0.9372 - val_loss: 1.0375 - val_auc_3: 0.7874
# Epoch 13/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.5190 - auc_3: 0.9367 - val_loss: 1.0448 - val_auc_3: 0.7864
# Epoch 14/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.4682 - auc_3: 0.9449 - val_loss: 1.0535 - val_auc_3: 0.7856
# Epoch 15/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.5239 - auc_3: 0.9308 - val_loss: 1.0595 - val_auc_3: 0.7836
# Epoch 16/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.5009 - auc_3: 0.9395 - val_loss: 1.0644 - val_auc_3: 0.7840
# Epoch 17/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.5014 - auc_3: 0.9354 - val_loss: 1.0665 - val_auc_3: 0.7844
# Epoch 18/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.5120 - auc_3: 0.9346 - val_loss: 1.0656 - val_auc_3: 0.7851
# Epoch 19/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.5050 - auc_3: 0.9363 - val_loss: 1.0641 - val_auc_3: 0.7845
# Epoch 20/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.5043 - auc_3: 0.9386 - val_loss: 1.0611 - val_auc_3: 0.7854
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# efficientnet-b5 (Functional) (None, 19, 19, 2048)      28513520
# _________________________________________________________________
# global_average_pooling2d_4 ( (None, 2048)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 4)                 8196
# =================================================================
# Total params: 28,521,716
# Trainable params: 28,348,980
# Non-trainable params: 172,736
# _________________________________________________________________
# Epoch 1/20
# 37/37 [==============================] - 270s 3s/step - loss: 1.1202 - auc_4: 0.6482 - val_loss: 2.0632 - val_auc_4: 0.6411
# Epoch 2/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.9798 - auc_4: 0.7246 - val_loss: 1.2132 - val_auc_4: 0.7565
# Epoch 3/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.9216 - auc_4: 0.7642 - val_loss: 1.3503 - val_auc_4: 0.7324
# Epoch 4/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.8938 - auc_4: 0.7939 - val_loss: 1.0967 - val_auc_4: 0.7446
# Epoch 5/20
# 37/37 [==============================] - 40s 1s/step - loss: 0.8291 - auc_4: 0.8170 - val_loss: 1.0939 - val_auc_4: 0.7507
# Epoch 6/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.8286 - auc_4: 0.8233 - val_loss: 1.2958 - val_auc_4: 0.7359
# Epoch 7/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.7840 - auc_4: 0.8450 - val_loss: 1.0095 - val_auc_4: 0.7543
# Epoch 8/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.7258 - auc_4: 0.8670 - val_loss: 1.1189 - val_auc_4: 0.7412
# Epoch 9/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.7180 - auc_4: 0.8672 - val_loss: 1.0531 - val_auc_4: 0.7718
# Epoch 10/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.6463 - auc_4: 0.8945 - val_loss: 1.3801 - val_auc_4: 0.7306
# Epoch 11/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.5729 - auc_4: 0.9204 - val_loss: 1.1926 - val_auc_4: 0.7622
# Epoch 12/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.4613 - auc_4: 0.9496 - val_loss: 1.1747 - val_auc_4: 0.7653
# Epoch 13/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.4108 - auc_4: 0.9571 - val_loss: 1.1742 - val_auc_4: 0.7646
# Epoch 14/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.3637 - auc_4: 0.9697 - val_loss: 1.1879 - val_auc_4: 0.7664
# Epoch 15/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.3468 - auc_4: 0.9736 - val_loss: 1.2078 - val_auc_4: 0.7673
# Epoch 16/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.3573 - auc_4: 0.9710 - val_loss: 1.2177 - val_auc_4: 0.7689
# Epoch 17/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.3503 - auc_4: 0.9725 - val_loss: 1.2251 - val_auc_4: 0.7701
# Epoch 18/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.3605 - auc_4: 0.9677 - val_loss: 1.2287 - val_auc_4: 0.7729
# Epoch 19/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.3480 - auc_4: 0.9715 - val_loss: 1.2278 - val_auc_4: 0.7730
# Epoch 20/20
# 37/37 [==============================] - 39s 1s/step - loss: 0.3360 - auc_4: 0.9739 - val_loss: 1.2276 - val_auc_4: 0.7743
