# %% [markdown]
# 感谢大佬[h053473666](https://www.kaggle.com/h053473666)的数据集[https://www.kaggle.com/h053473666/siimcovid19-512-img-png-600-study-png](https://www.kaggle.com/h053473666/siimcovid19-512-img-png-600-study-png)

# %%
# !pip install efficientnet -q
# Out:
# WARNING: Running pip as root will break packages and permissions. You should install packages reliably by using venv: https://pip.pypa.io/warnings/venv

# %%
import os

import efficientnet.tfkeras as efn
import numpy as np
import pandas as pd
from kaggle_datasets import KaggleDatasets
from sklearn.model_selection import train_test_split
import tensorflow as tf
from sklearn.model_selection import KFold

# %%
SEED = 42        #随机数种子，用来KFold分数据集
FOLDS = 5        #交叉验证次数
BATCH_SIZES = 16  
EPOCHS = 30
EFF_NETS = 5     #efn选择，数值0-7之间
ls = 0.015       # 标签平滑，可以尝试0.015，不用请写0，可抗过拟合
IMAGE_SIZE = (224, 240, 260, 300, 380, 456, 528, 600, 512)

SIIM_para = {}
SIIM_para['SEED'] = SEED
SIIM_para['FOLDS'] = FOLDS
SIIM_para['BATCH_SIZES'] = BATCH_SIZES
SIIM_para['EPOCHS'] = EPOCHS
SIIM_para['EFF_NETS'] = EFF_NETS
SIIM_para['IMAGE_SIZE'] = IMAGE_SIZE[8]
print('SIIM_parameters: {}'.format(SIIM_para))
# Out:
# SIIM_parameters: {'SEED': 42, 'FOLDS': 5, 'BATCH_SIZES': 16, 'EPOCHS': 30, 'EFF_NETS': 5, 'IMAGE_SIZE': 512}

# %%
def get_lr_callback():
    lr_start   = 1e-6 # 初始学习率
    lr_max   =  2e-4# 最大学习率
    lr_min     = 1e-7 #最小学习率
    lr_ramp_ep =  10 # 用几个epoch达到最大学习率
    lr_sus_ep  =  2# 用最大的学习率跑几个epoch
    lr_decay   = .5 # 退火，常用方法
   
    def lrfn(epoch):
        if epoch < lr_ramp_ep:
            lr = (lr_max - lr_start) / lr_ramp_ep * epoch + lr_start
            
        elif epoch < lr_ramp_ep + lr_sus_ep:
            lr = lr_max
            
        else:
            lr = (lr_max - lr_min) * lr_decay**(epoch - lr_ramp_ep - lr_sus_ep) + lr_min
            
        return lr

    lr_callback = tf.keras.callbacks.LearningRateScheduler(lrfn, verbose=False)
    return lr_callback

# %%
def auto_select_strategy():
    try:
        tpu = tf.distribute.cluster_resolver.TPUClusterResolver()
        tf.config.experimental_connect_to_cluster(tpu)
        tf.tpu.experimental.initialize_tpu_system(tpu)
        strategy = tf.distribute.experimental.TPUStrategy(tpu)
        print("Running on TPU:", tpu.master())
    except ValueError:
        strategy = tf.distribute.get_strategy()
    print(f"Running on {strategy.num_replicas_in_sync} replicas")
    
    return strategy

# %%
def build_decoder(with_labels=True, target_size=(256, 256), ext='jpg'):
    def decode(path):
        file_bytes = tf.io.read_file(path)

        if ext == 'png':
            img = tf.image.decode_png(file_bytes, channels=3)
        elif ext in ['jpg', 'jpeg']:
            img = tf.image.decode_jpeg(file_bytes, channels=3)
        else:
            raise ValueError("Image extension not supported")
        img = tf.cast(img, tf.float32) / 255.0
        img = tf.image.resize(img, target_size)

        return img
    
    def decode_with_labels(path, label):
        return decode(path), label
    
    return decode_with_labels if with_labels else decode


def build_augmenter(with_labels=True):
    def augment(img):
        if tf.random.uniform(()) > 0.5:
            img = tf.image.flip_left_right(img)
    
        if tf.random.uniform(()) > 0.4:
            img = tf.image.flip_up_down(img)

        if tf.random.uniform(()) > 0.5:
            img = tf.image.rot90(img, k=1)

        if tf.random.uniform(()) > 0.45:
            img = tf.image.random_saturation(img, 0.7, 1.3)

#        if tf.random.uniform(()) > 0.45:
#            img = tf.image.random_contrast(img, 0.8, 1.2)
#            
#        if tf.random.uniform(()) > 0.45:
#            img = tf.image.random_brightness(img, 0.1)
        return img
    
    def augment_with_labels(img, label):
        return augment(img), label
    
    return augment_with_labels if with_labels else augment


def build_dataset(paths, labels=None, bsize=128, cache=True,
                  decode_fn=None, augment_fn=None,
                  augment=True, repeat=True, shuffle=1024, 
                  cache_dir=""):
    if cache_dir != "" and cache is True:
        os.makedirs(cache_dir, exist_ok=True)
    
    if decode_fn is None:
        decode_fn = build_decoder(labels is not None)
    
    if augment_fn is None:
        augment_fn = build_augmenter(labels is not None)
    
    AUTO = tf.data.experimental.AUTOTUNE
    slices = paths if labels is None else (paths, labels)
    
    dset = tf.data.Dataset.from_tensor_slices(slices)
    dset = dset.map(decode_fn, num_parallel_calls=AUTO)
    dset = dset.cache(cache_dir) if cache else dset
    dset = dset.map(augment_fn, num_parallel_calls=AUTO) if augment else dset
    dset = dset.repeat() if repeat else dset
    dset = dset.shuffle(shuffle) if shuffle else dset
    dset = dset.batch(bsize).prefetch(AUTO)
    
    return dset

# %%
COMPETITION_NAME = "siimcovid19-512-img-png-600-study-png"
strategy = auto_select_strategy()
REPLICAS = strategy.num_replicas_in_sync * BATCH_SIZES
GCS_DS_PATH = KaggleDatasets().get_gcs_path(COMPETITION_NAME)
# Out:
# Running on TPU: grpc://10.0.0.2:8470
# Running on 8 replicas

# %%
load_dir = f"/kaggle/input/{COMPETITION_NAME}/"
df = pd.read_csv('../input/siimcov19csv/train.csv')
label_cols = df.columns[4]

# %%
def build_model(dim=128, ef=0):
    
    inp = tf.keras.layers.Input(shape=(dim,dim,3))
    base = EFNS[ef](input_shape=(dim,dim,3),weights='imagenet',include_top=False)
    x = base(inp)
    x = tf.keras.layers.GlobalAveragePooling2D()(x)

    x = tf.keras.layers.Dense(1024, activation='relu')(x)
    x = tf.keras.layers.Dropout(0.2)(x)

    x = tf.keras.layers.Dense(1, activation='sigmoid')(x)
    
    model = tf.keras.Model(inputs=inp,outputs=x)
    opt = tf.keras.optimizers.Adam(learning_rate=0.001)
    loss = tf.keras.losses.BinaryCrossentropy(label_smoothing=ls) 
    model.compile(optimizer=opt,loss=loss,metrics=['AUC'])
    model.summary()
    
    return model

# %%
skf = KFold(n_splits=FOLDS,shuffle=True,random_state=SEED)
df['fold'] = -1
for fold, (train_idx, val_idx) in enumerate(skf.split(df, groups = df.StudyInstanceUID.tolist())):
    df.loc[val_idx, 'fold'] = fold

# %%
EFNS = [efn.EfficientNetB0, efn.EfficientNetB1, efn.EfficientNetB2, efn.EfficientNetB3, 
        efn.EfficientNetB4, efn.EfficientNetB5, efn.EfficientNetB6, efn.EfficientNetB7]


for i in range(5):
    
    valid_paths = GCS_DS_PATH + '/image/' + df[df['fold'] == i]['id'] + '.png' #"/train/"
    train_paths = GCS_DS_PATH + '/image/' + df[df['fold'] != i]['id'] + '.png' #"/train/" 
    valid_labels = df[df['fold'] == i][label_cols].values
    train_labels = df[df['fold'] != i][label_cols].values



    decoder = build_decoder(with_labels=True, target_size=(IMAGE_SIZE[8], IMAGE_SIZE[8]), ext='png')
    test_decoder = build_decoder(with_labels=False, target_size=(IMAGE_SIZE[8], IMAGE_SIZE[8]),ext='png')

    train_dataset = build_dataset(
        train_paths, train_labels, bsize=REPLICAS, decode_fn=decoder
    )

    valid_dataset = build_dataset(
        valid_paths, valid_labels, bsize=REPLICAS, decode_fn=decoder,
        repeat=False, shuffle=False, augment=False
    )

    try:
        n_labels = train_labels.shape[1]
    except:
        n_labels = 1

    with strategy.scope():
        model = build_model(dim=IMAGE_SIZE[8],ef=EFF_NETS)

    steps_per_epoch = train_paths.shape[0] // REPLICAS
    checkpoint = tf.keras.callbacks.ModelCheckpoint(
        f'model{i}.h5', save_best_only=True, monitor='val_loss', mode='min')


    history = model.fit(
        train_dataset, 
        epochs=EPOCHS,
        verbose=1,
        callbacks=[checkpoint, get_lr_callback()],
        steps_per_epoch=steps_per_epoch,
        validation_data=valid_dataset)

    hist_df = pd.DataFrame(history.history)
    hist_df.to_csv(f'history{i}.csv')
# Out:
# Downloading data from https://github.com/Callidior/keras-applications/releases/download/efficientnet/efficientnet-b5_weights_tf_dim_ordering_tf_kernels_autoaugment_notop.h5
# 115515392/115515256 [==============================] - 2s 0us/step
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 512, 512, 3)]     0
# _________________________________________________________________
# efficientnet-b5 (Functional) (None, 16, 16, 2048)      28513520
# _________________________________________________________________
# global_average_pooling2d (Gl (None, 2048)              0
# _________________________________________________________________
# dense (Dense)                (None, 1024)              2098176
# _________________________________________________________________
# dropout (Dropout)            (None, 1024)              0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 30,612,721
# Trainable params: 30,439,985
# Non-trainable params: 172,736
# _________________________________________________________________
# Epoch 1/30
# 39/39 [==============================] - 331s 4s/step - loss: 0.7023 - auc: 0.5082 - val_loss: 0.6777 - val_auc: 0.5360
# Epoch 2/30
# 39/39 [==============================] - 24s 622ms/step - loss: 0.6521 - auc: 0.5975 - val_loss: 0.6466 - val_auc: 0.6595
# Epoch 3/30
# 39/39 [==============================] - 24s 617ms/step - loss: 0.5599 - auc: 0.7430 - val_loss: 0.5889 - val_auc: 0.7616
# Epoch 4/30
# 39/39 [==============================] - 24s 618ms/step - loss: 0.5038 - auc: 0.8098 - val_loss: 0.5176 - val_auc: 0.8070
# Epoch 5/30
# 39/39 [==============================] - 24s 617ms/step - loss: 0.4940 - auc: 0.8212 - val_loss: 0.5046 - val_auc: 0.8279
# Epoch 6/30
# 39/39 [==============================] - 24s 625ms/step - loss: 0.4686 - auc: 0.8422 - val_loss: 0.4722 - val_auc: 0.8385
# Epoch 7/30
# 39/39 [==============================] - 24s 616ms/step - loss: 0.4492 - auc: 0.8546 - val_loss: 0.4381 - val_auc: 0.8524
# Epoch 8/30
# 39/39 [==============================] - 24s 616ms/step - loss: 0.4285 - auc: 0.8691 - val_loss: 0.4664 - val_auc: 0.8457
# Epoch 9/30
# 39/39 [==============================] - 24s 617ms/step - loss: 0.4344 - auc: 0.8695 - val_loss: 0.4343 - val_auc: 0.8563
# Epoch 10/30
# 39/39 [==============================] - 24s 624ms/step - loss: 0.4075 - auc: 0.8859 - val_loss: 0.4526 - val_auc: 0.8599
# Epoch 11/30
# 39/39 [==============================] - 24s 619ms/step - loss: 0.3957 - auc: 0.8934 - val_loss: 0.4728 - val_auc: 0.8640
# Epoch 12/30
# 39/39 [==============================] - 24s 621ms/step - loss: 0.3964 - auc: 0.8945 - val_loss: 0.4301 - val_auc: 0.8655
# Epoch 13/30
# 39/39 [==============================] - 24s 616ms/step - loss: 0.3761 - auc: 0.9070 - val_loss: 0.5541 - val_auc: 0.8641
# Epoch 14/30
# 39/39 [==============================] - 24s 621ms/step - loss: 0.3377 - auc: 0.9248 - val_loss: 0.4449 - val_auc: 0.8722
# Epoch 15/30
# 39/39 [==============================] - 24s 623ms/step - loss: 0.3245 - auc: 0.9336 - val_loss: 0.4448 - val_auc: 0.8698
# Epoch 16/30
# 39/39 [==============================] - 24s 621ms/step - loss: 0.2923 - auc: 0.9474 - val_loss: 0.4500 - val_auc: 0.8726
# Epoch 17/30
# 39/39 [==============================] - 24s 626ms/step - loss: 0.2924 - auc: 0.9488 - val_loss: 0.4540 - val_auc: 0.8722
# Epoch 18/30
# 39/39 [==============================] - 24s 622ms/step - loss: 0.2635 - auc: 0.9592 - val_loss: 0.4519 - val_auc: 0.8733
# Epoch 19/30
# 39/39 [==============================] - 24s 622ms/step - loss: 0.2779 - auc: 0.9536 - val_loss: 0.4472 - val_auc: 0.8754
# Epoch 20/30
# 39/39 [==============================] - 24s 611ms/step - loss: 0.2747 - auc: 0.9564 - val_loss: 0.4434 - val_auc: 0.8766
# Epoch 21/30
# 39/39 [==============================] - 24s 617ms/step - loss: 0.2721 - auc: 0.9570 - val_loss: 0.4428 - val_auc: 0.8770
# Epoch 22/30
# 39/39 [==============================] - 24s 620ms/step - loss: 0.2627 - auc: 0.9600 - val_loss: 0.4451 - val_auc: 0.8768
# Epoch 23/30
# 39/39 [==============================] - 24s 619ms/step - loss: 0.2683 - auc: 0.9591 - val_loss: 0.4496 - val_auc: 0.8762
# Epoch 24/30
# 39/39 [==============================] - 24s 626ms/step - loss: 0.2746 - auc: 0.9547 - val_loss: 0.4544 - val_auc: 0.8753
# Epoch 25/30
# 39/39 [==============================] - 24s 613ms/step - loss: 0.2747 - auc: 0.9550 - val_loss: 0.4564 - val_auc: 0.8743
# Epoch 26/30
# 39/39 [==============================] - 24s 616ms/step - loss: 0.2750 - auc: 0.9561 - val_loss: 0.4583 - val_auc: 0.8734
# Epoch 27/30
# 39/39 [==============================] - 24s 616ms/step - loss: 0.2864 - auc: 0.9501 - val_loss: 0.4597 - val_auc: 0.8724
# Epoch 28/30
# 39/39 [==============================] - 24s 615ms/step - loss: 0.2644 - auc: 0.9581 - val_loss: 0.4602 - val_auc: 0.8726
# Epoch 29/30
# 39/39 [==============================] - 24s 618ms/step - loss: 0.2803 - auc: 0.9541 - val_loss: 0.4620 - val_auc: 0.8716
# Epoch 30/30
# 39/39 [==============================] - 24s 625ms/step - loss: 0.2616 - auc: 0.9614 - val_loss: 0.4614 - val_auc: 0.8713
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 512, 512, 3)]     0
# _________________________________________________________________
# efficientnet-b5 (Functional) (None, 16, 16, 2048)      28513520
# _________________________________________________________________
# global_average_pooling2d_1 ( (None, 2048)              0
# _________________________________________________________________
# dense_2 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_3 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 30,612,721
# Trainable params: 30,439,985
# Non-trainable params: 172,736
# _________________________________________________________________
# Epoch 1/30
# 39/39 [==============================] - 279s 3s/step - loss: 0.7175 - auc: 0.4843 - val_loss: 0.6962 - val_auc: 0.5181
# Epoch 2/30
# 39/39 [==============================] - 24s 620ms/step - loss: 0.6626 - auc: 0.5611 - val_loss: 0.6983 - val_auc: 0.6376
# Epoch 3/30
# 39/39 [==============================] - 24s 623ms/step - loss: 0.5696 - auc: 0.7166 - val_loss: 0.6643 - val_auc: 0.7660
# Epoch 4/30
# 39/39 [==============================] - 24s 617ms/step - loss: 0.5130 - auc: 0.7877 - val_loss: 0.6174 - val_auc: 0.8080
# Epoch 5/30
# 39/39 [==============================] - 24s 619ms/step - loss: 0.4770 - auc: 0.8262 - val_loss: 0.5383 - val_auc: 0.8247
# Epoch 6/30
# 39/39 [==============================] - 25s 629ms/step - loss: 0.4581 - auc: 0.8451 - val_loss: 0.4864 - val_auc: 0.8313
# Epoch 7/30
# 39/39 [==============================] - 24s 623ms/step - loss: 0.4406 - auc: 0.8579 - val_loss: 0.5630 - val_auc: 0.8441
# Epoch 8/30
# 39/39 [==============================] - 25s 633ms/step - loss: 0.4243 - auc: 0.8659 - val_loss: 0.4786 - val_auc: 0.8435
# Epoch 9/30
# 39/39 [==============================] - 24s 624ms/step - loss: 0.4048 - auc: 0.8853 - val_loss: 0.5243 - val_auc: 0.8529
# Epoch 10/30
# 39/39 [==============================] - 24s 627ms/step - loss: 0.4082 - auc: 0.8827 - val_loss: 0.4708 - val_auc: 0.8570
# Epoch 11/30
# 39/39 [==============================] - 24s 623ms/step - loss: 0.4010 - auc: 0.8874 - val_loss: 0.5146 - val_auc: 0.8554
# Epoch 12/30
# 39/39 [==============================] - 24s 615ms/step - loss: 0.3900 - auc: 0.8954 - val_loss: 0.4596 - val_auc: 0.8597
# Epoch 13/30
# 39/39 [==============================] - 24s 618ms/step - loss: 0.3512 - auc: 0.9175 - val_loss: 0.4823 - val_auc: 0.8509
# Epoch 14/30
# 39/39 [==============================] - 24s 627ms/step - loss: 0.3209 - auc: 0.9333 - val_loss: 0.4846 - val_auc: 0.8559
# Epoch 15/30
# 39/39 [==============================] - 24s 618ms/step - loss: 0.2963 - auc: 0.9443 - val_loss: 0.4962 - val_auc: 0.8528
# Epoch 16/30
# 39/39 [==============================] - 24s 617ms/step - loss: 0.2760 - auc: 0.9552 - val_loss: 0.5229 - val_auc: 0.8561
# Epoch 17/30
# 39/39 [==============================] - 24s 619ms/step - loss: 0.2716 - auc: 0.9562 - val_loss: 0.5152 - val_auc: 0.8543
# Epoch 18/30
# 39/39 [==============================] - 24s 616ms/step - loss: 0.2631 - auc: 0.9592 - val_loss: 0.5221 - val_auc: 0.8550
# Epoch 19/30
# 39/39 [==============================] - 24s 625ms/step - loss: 0.2639 - auc: 0.9593 - val_loss: 0.5202 - val_auc: 0.8553
# Epoch 20/30
# 39/39 [==============================] - 24s 617ms/step - loss: 0.2684 - auc: 0.9568 - val_loss: 0.5246 - val_auc: 0.8544
# Epoch 21/30
# 39/39 [==============================] - 24s 620ms/step - loss: 0.2545 - auc: 0.9619 - val_loss: 0.5324 - val_auc: 0.8532
# Epoch 22/30
# 39/39 [==============================] - 24s 619ms/step - loss: 0.2712 - auc: 0.9557 - val_loss: 0.5375 - val_auc: 0.8538
# Epoch 23/30
# 39/39 [==============================] - 24s 624ms/step - loss: 0.2417 - auc: 0.9672 - val_loss: 0.5408 - val_auc: 0.8537
# Epoch 24/30
# 39/39 [==============================] - 26s 667ms/step - loss: 0.2679 - auc: 0.9561 - val_loss: 0.5404 - val_auc: 0.8551
# Epoch 25/30
# 39/39 [==============================] - 25s 635ms/step - loss: 0.2719 - auc: 0.9558 - val_loss: 0.5416 - val_auc: 0.8549
# Epoch 26/30
# 39/39 [==============================] - 24s 620ms/step - loss: 0.2677 - auc: 0.9569 - val_loss: 0.5418 - val_auc: 0.8547
# Epoch 27/30
# 39/39 [==============================] - 24s 628ms/step - loss: 0.2753 - auc: 0.9526 - val_loss: 0.5423 - val_auc: 0.8546
# Epoch 28/30
# 39/39 [==============================] - 24s 624ms/step - loss: 0.2631 - auc: 0.9591 - val_loss: 0.5426 - val_auc: 0.8541
# Epoch 29/30
# 39/39 [==============================] - 24s 627ms/step - loss: 0.2601 - auc: 0.9602 - val_loss: 0.5425 - val_auc: 0.8542
# Epoch 30/30
# 39/39 [==============================] - 24s 625ms/step - loss: 0.2540 - auc: 0.9636 - val_loss: 0.5419 - val_auc: 0.8549
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_5 (InputLayer)         [(None, 512, 512, 3)]     0
# _________________________________________________________________
# efficientnet-b5 (Functional) (None, 16, 16, 2048)      28513520
# _________________________________________________________________
# global_average_pooling2d_2 ( (None, 2048)              0
# _________________________________________________________________
# dense_4 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 30,612,721
# Trainable params: 30,439,985
# Non-trainable params: 172,736
# _________________________________________________________________
# Epoch 1/30
# 39/39 [==============================] - 277s 3s/step - loss: 0.6794 - auc: 0.5175 - val_loss: 0.7038 - val_auc: 0.4386
# Epoch 2/30
# 39/39 [==============================] - 24s 621ms/step - loss: 0.6381 - auc: 0.5808 - val_loss: 0.6554 - val_auc: 0.6601
# Epoch 3/30
# 39/39 [==============================] - 24s 621ms/step - loss: 0.5564 - auc: 0.7502 - val_loss: 0.5960 - val_auc: 0.7591
# Epoch 4/30
# 39/39 [==============================] - 24s 625ms/step - loss: 0.4903 - auc: 0.8137 - val_loss: 0.5388 - val_auc: 0.7897
# Epoch 5/30
# 39/39 [==============================] - 25s 629ms/step - loss: 0.4772 - auc: 0.8309 - val_loss: 0.5049 - val_auc: 0.8041
# Epoch 6/30
# 39/39 [==============================] - 24s 622ms/step - loss: 0.4345 - auc: 0.8641 - val_loss: 0.4916 - val_auc: 0.8197
# Epoch 7/30
# 39/39 [==============================] - 24s 618ms/step - loss: 0.4353 - auc: 0.8614 - val_loss: 0.4903 - val_auc: 0.8282
# Epoch 8/30
# 39/39 [==============================] - 24s 620ms/step - loss: 0.4150 - auc: 0.8784 - val_loss: 0.4901 - val_auc: 0.8317
# Epoch 9/30
# 39/39 [==============================] - 24s 622ms/step - loss: 0.4196 - auc: 0.8756 - val_loss: 0.5060 - val_auc: 0.8403
# Epoch 10/30
# 39/39 [==============================] - 24s 623ms/step - loss: 0.3900 - auc: 0.8940 - val_loss: 0.5011 - val_auc: 0.8486
# Epoch 11/30
# 39/39 [==============================] - 25s 635ms/step - loss: 0.3829 - auc: 0.9000 - val_loss: 0.4613 - val_auc: 0.8503
# Epoch 12/30
# 39/39 [==============================] - 24s 619ms/step - loss: 0.3762 - auc: 0.9062 - val_loss: 0.4945 - val_auc: 0.8488
# Epoch 13/30
# 39/39 [==============================] - 24s 623ms/step - loss: 0.3537 - auc: 0.9168 - val_loss: 0.4963 - val_auc: 0.8460
# Epoch 14/30
# 39/39 [==============================] - 25s 634ms/step - loss: 0.3305 - auc: 0.9300 - val_loss: 0.5430 - val_auc: 0.8489
# Epoch 15/30
# 39/39 [==============================] - 24s 625ms/step - loss: 0.3140 - auc: 0.9382 - val_loss: 0.5074 - val_auc: 0.8478
# Epoch 16/30
# 39/39 [==============================] - 24s 619ms/step - loss: 0.2849 - auc: 0.9499 - val_loss: 0.5119 - val_auc: 0.8489
# Epoch 17/30
# 39/39 [==============================] - 24s 618ms/step - loss: 0.2786 - auc: 0.9541 - val_loss: 0.5138 - val_auc: 0.8481
# Epoch 18/30
# 39/39 [==============================] - 24s 621ms/step - loss: 0.2721 - auc: 0.9578 - val_loss: 0.5235 - val_auc: 0.8493
# Epoch 19/30
# 39/39 [==============================] - 24s 621ms/step - loss: 0.2609 - auc: 0.9609 - val_loss: 0.5261 - val_auc: 0.8489
# Epoch 20/30
# 39/39 [==============================] - 24s 616ms/step - loss: 0.2648 - auc: 0.9590 - val_loss: 0.5241 - val_auc: 0.8503
# Epoch 21/30
# 39/39 [==============================] - 24s 622ms/step - loss: 0.2607 - auc: 0.9602 - val_loss: 0.5215 - val_auc: 0.8521
# Epoch 22/30
# 39/39 [==============================] - 24s 627ms/step - loss: 0.2688 - auc: 0.9570 - val_loss: 0.5217 - val_auc: 0.8518
# Epoch 23/30
# 39/39 [==============================] - 24s 621ms/step - loss: 0.2676 - auc: 0.9572 - val_loss: 0.5230 - val_auc: 0.8526
# Epoch 24/30
# 39/39 [==============================] - 24s 622ms/step - loss: 0.2577 - auc: 0.9604 - val_loss: 0.5237 - val_auc: 0.8520
# Epoch 25/30
# 39/39 [==============================] - 24s 627ms/step - loss: 0.2423 - auc: 0.9666 - val_loss: 0.5224 - val_auc: 0.8521
# Epoch 26/30
# 39/39 [==============================] - 24s 620ms/step - loss: 0.2581 - auc: 0.9618 - val_loss: 0.5227 - val_auc: 0.8513
# Epoch 27/30
# 39/39 [==============================] - 24s 622ms/step - loss: 0.2634 - auc: 0.9597 - val_loss: 0.5222 - val_auc: 0.8515
# Epoch 28/30
# 39/39 [==============================] - 24s 622ms/step - loss: 0.2671 - auc: 0.9574 - val_loss: 0.5231 - val_auc: 0.8504
# Epoch 29/30
# 39/39 [==============================] - 24s 620ms/step - loss: 0.2576 - auc: 0.9613 - val_loss: 0.5236 - val_auc: 0.8496
# Epoch 30/30
# 39/39 [==============================] - 24s 620ms/step - loss: 0.2653 - auc: 0.9569 - val_loss: 0.5242 - val_auc: 0.8495
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_7 (InputLayer)         [(None, 512, 512, 3)]     0
# _________________________________________________________________
# efficientnet-b5 (Functional) (None, 16, 16, 2048)      28513520
# _________________________________________________________________
# global_average_pooling2d_3 ( (None, 2048)              0
# _________________________________________________________________
# dense_6 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 30,612,721
# Trainable params: 30,439,985
# Non-trainable params: 172,736
# _________________________________________________________________
# Epoch 1/30
# 39/39 [==============================] - 270s 3s/step - loss: 0.6846 - auc: 0.5481 - val_loss: 0.7106 - val_auc: 0.6181
# Epoch 2/30
# 39/39 [==============================] - 24s 623ms/step - loss: 0.6422 - auc: 0.6030 - val_loss: 0.6885 - val_auc: 0.6985
# Epoch 3/30
# 39/39 [==============================] - 24s 618ms/step - loss: 0.5523 - auc: 0.7477 - val_loss: 0.6481 - val_auc: 0.7507
# Epoch 4/30
# 39/39 [==============================] - 24s 626ms/step - loss: 0.5019 - auc: 0.8092 - val_loss: 0.5442 - val_auc: 0.7879
# Epoch 5/30
# 39/39 [==============================] - 24s 619ms/step - loss: 0.4826 - auc: 0.8233 - val_loss: 0.5373 - val_auc: 0.8049
# Epoch 6/30
# 39/39 [==============================] - 24s 625ms/step - loss: 0.4553 - auc: 0.8509 - val_loss: 0.5188 - val_auc: 0.8275
# Epoch 7/30
# 39/39 [==============================] - 24s 620ms/step - loss: 0.4514 - auc: 0.8530 - val_loss: 0.4760 - val_auc: 0.8323
# Epoch 8/30
# 39/39 [==============================] - 24s 623ms/step - loss: 0.4385 - auc: 0.8635 - val_loss: 0.4636 - val_auc: 0.8397
# Epoch 9/30
# 39/39 [==============================] - 24s 621ms/step - loss: 0.4187 - auc: 0.8768 - val_loss: 0.4676 - val_auc: 0.8373
# Epoch 10/30
# 39/39 [==============================] - 24s 618ms/step - loss: 0.4081 - auc: 0.8848 - val_loss: 0.4851 - val_auc: 0.8434
# Epoch 11/30
# 39/39 [==============================] - 24s 619ms/step - loss: 0.3910 - auc: 0.8954 - val_loss: 0.4693 - val_auc: 0.8287
# Epoch 12/30
# 39/39 [==============================] - 24s 620ms/step - loss: 0.3773 - auc: 0.9044 - val_loss: 0.4607 - val_auc: 0.8349
# Epoch 13/30
# 39/39 [==============================] - 24s 619ms/step - loss: 0.3524 - auc: 0.9179 - val_loss: 0.4648 - val_auc: 0.8523
# Epoch 14/30
# 39/39 [==============================] - 24s 613ms/step - loss: 0.3525 - auc: 0.9206 - val_loss: 0.4758 - val_auc: 0.8443
# Epoch 15/30
# 39/39 [==============================] - 24s 620ms/step - loss: 0.3101 - auc: 0.9391 - val_loss: 0.4805 - val_auc: 0.8536
# Epoch 16/30
# 39/39 [==============================] - 24s 624ms/step - loss: 0.3084 - auc: 0.9413 - val_loss: 0.4693 - val_auc: 0.8543
# Epoch 17/30
# 39/39 [==============================] - 24s 622ms/step - loss: 0.2917 - auc: 0.9498 - val_loss: 0.4745 - val_auc: 0.8551
# Epoch 18/30
# 39/39 [==============================] - 24s 619ms/step - loss: 0.2736 - auc: 0.9564 - val_loss: 0.4765 - val_auc: 0.8554
# Epoch 19/30
# 39/39 [==============================] - 26s 662ms/step - loss: 0.2869 - auc: 0.9500 - val_loss: 0.4747 - val_auc: 0.8559
# Epoch 20/30
# 39/39 [==============================] - 24s 624ms/step - loss: 0.2751 - auc: 0.9549 - val_loss: 0.4752 - val_auc: 0.8577
# Epoch 21/30
# 39/39 [==============================] - 24s 619ms/step - loss: 0.2723 - auc: 0.9561 - val_loss: 0.4774 - val_auc: 0.8581
# Epoch 22/30
# 39/39 [==============================] - 24s 621ms/step - loss: 0.2763 - auc: 0.9543 - val_loss: 0.4805 - val_auc: 0.8584
# Epoch 23/30
# 39/39 [==============================] - 24s 618ms/step - loss: 0.2683 - auc: 0.9595 - val_loss: 0.4828 - val_auc: 0.8586
# Epoch 24/30
# 39/39 [==============================] - 24s 616ms/step - loss: 0.2884 - auc: 0.9480 - val_loss: 0.4837 - val_auc: 0.8585
# Epoch 25/30
# 39/39 [==============================] - 24s 619ms/step - loss: 0.2874 - auc: 0.9495 - val_loss: 0.4837 - val_auc: 0.8580
# Epoch 26/30
# 39/39 [==============================] - 24s 620ms/step - loss: 0.2802 - auc: 0.9520 - val_loss: 0.4834 - val_auc: 0.8585
# Epoch 27/30
# 39/39 [==============================] - 24s 618ms/step - loss: 0.2752 - auc: 0.9537 - val_loss: 0.4830 - val_auc: 0.8583
# Epoch 28/30
# 39/39 [==============================] - 24s 622ms/step - loss: 0.2827 - auc: 0.9520 - val_loss: 0.4826 - val_auc: 0.8579
# Epoch 29/30
# 39/39 [==============================] - 24s 623ms/step - loss: 0.2713 - auc: 0.9564 - val_loss: 0.4818 - val_auc: 0.8581
# Epoch 30/30
# 39/39 [==============================] - 24s 616ms/step - loss: 0.2695 - auc: 0.9555 - val_loss: 0.4818 - val_auc: 0.8576
# Model: "model_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_9 (InputLayer)         [(None, 512, 512, 3)]     0
# _________________________________________________________________
# efficientnet-b5 (Functional) (None, 16, 16, 2048)      28513520
# _________________________________________________________________
# global_average_pooling2d_4 ( (None, 2048)              0
# _________________________________________________________________
# dense_8 (Dense)              (None, 1024)              2098176
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 1024)              0
# _________________________________________________________________
# dense_9 (Dense)              (None, 1)                 1025
# =================================================================
# Total params: 30,612,721
# Trainable params: 30,439,985
# Non-trainable params: 172,736
# _________________________________________________________________
# Epoch 1/30
# 39/39 [==============================] - 271s 3s/step - loss: 0.6720 - auc: 0.5146 - val_loss: 0.6533 - val_auc: 0.4320
# Epoch 2/30
# 39/39 [==============================] - 24s 621ms/step - loss: 0.6338 - auc: 0.5940 - val_loss: 0.6349 - val_auc: 0.6504
# Epoch 3/30
# 39/39 [==============================] - 24s 628ms/step - loss: 0.5507 - auc: 0.7485 - val_loss: 0.5701 - val_auc: 0.7666
# Epoch 4/30
# 39/39 [==============================] - 24s 619ms/step - loss: 0.4972 - auc: 0.8055 - val_loss: 0.5396 - val_auc: 0.8100
# Epoch 5/30
# 39/39 [==============================] - 24s 617ms/step - loss: 0.4722 - auc: 0.8383 - val_loss: 0.4865 - val_auc: 0.8235
# Epoch 6/30
# 39/39 [==============================] - 24s 619ms/step - loss: 0.4476 - auc: 0.8572 - val_loss: 0.4821 - val_auc: 0.8311
# Epoch 7/30
# 39/39 [==============================] - 24s 624ms/step - loss: 0.4428 - auc: 0.8569 - val_loss: 0.4769 - val_auc: 0.8384
# Epoch 8/30
# 39/39 [==============================] - 24s 619ms/step - loss: 0.4327 - auc: 0.8682 - val_loss: 0.4728 - val_auc: 0.8380
# Epoch 9/30
# 39/39 [==============================] - 24s 617ms/step - loss: 0.4070 - auc: 0.8847 - val_loss: 0.4756 - val_auc: 0.8477
# Epoch 10/30
# 39/39 [==============================] - 24s 619ms/step - loss: 0.4096 - auc: 0.8826 - val_loss: 0.4574 - val_auc: 0.8539
# Epoch 11/30
# 39/39 [==============================] - 24s 625ms/step - loss: 0.3945 - auc: 0.8902 - val_loss: 0.5285 - val_auc: 0.8568
# Epoch 12/30
# 39/39 [==============================] - 24s 616ms/step - loss: 0.3840 - auc: 0.9002 - val_loss: 0.4866 - val_auc: 0.8419
# Epoch 13/30
# 39/39 [==============================] - 24s 622ms/step - loss: 0.3604 - auc: 0.9124 - val_loss: 0.4721 - val_auc: 0.8483
# Epoch 14/30
# 39/39 [==============================] - 24s 625ms/step - loss: 0.3326 - auc: 0.9251 - val_loss: 0.4721 - val_auc: 0.8600
# Epoch 15/30
# 39/39 [==============================] - 24s 623ms/step - loss: 0.3036 - auc: 0.9416 - val_loss: 0.4818 - val_auc: 0.8527
# Epoch 16/30
# 39/39 [==============================] - 24s 625ms/step - loss: 0.3022 - auc: 0.9406 - val_loss: 0.4827 - val_auc: 0.8536
# Epoch 17/30
# 39/39 [==============================] - 24s 616ms/step - loss: 0.2652 - auc: 0.9583 - val_loss: 0.4911 - val_auc: 0.8507
# Epoch 18/30
# 39/39 [==============================] - 24s 618ms/step - loss: 0.2814 - auc: 0.9512 - val_loss: 0.4929 - val_auc: 0.8517
# Epoch 19/30
# 39/39 [==============================] - 24s 615ms/step - loss: 0.2804 - auc: 0.9519 - val_loss: 0.4929 - val_auc: 0.8526
# Epoch 20/30
# 39/39 [==============================] - 24s 628ms/step - loss: 0.2768 - auc: 0.9538 - val_loss: 0.4909 - val_auc: 0.8540
# Epoch 21/30
# 39/39 [==============================] - 24s 621ms/step - loss: 0.2822 - auc: 0.9522 - val_loss: 0.4927 - val_auc: 0.8547
# Epoch 22/30
# 39/39 [==============================] - 24s 627ms/step - loss: 0.2606 - auc: 0.9607 - val_loss: 0.4980 - val_auc: 0.8538
# Epoch 23/30
# 39/39 [==============================] - 24s 620ms/step - loss: 0.2635 - auc: 0.9591 - val_loss: 0.5019 - val_auc: 0.8530
# Epoch 24/30
# 39/39 [==============================] - 24s 623ms/step - loss: 0.2731 - auc: 0.9555 - val_loss: 0.5033 - val_auc: 0.8532
# Epoch 25/30
# 39/39 [==============================] - 24s 624ms/step - loss: 0.2667 - auc: 0.9572 - val_loss: 0.5033 - val_auc: 0.8532
# Epoch 26/30
# 39/39 [==============================] - 24s 616ms/step - loss: 0.2792 - auc: 0.9529 - val_loss: 0.5044 - val_auc: 0.8523
# Epoch 27/30
# 39/39 [==============================] - 24s 623ms/step - loss: 0.2670 - auc: 0.9563 - val_loss: 0.5037 - val_auc: 0.8525
# Epoch 28/30
# 39/39 [==============================] - 24s 619ms/step - loss: 0.2661 - auc: 0.9580 - val_loss: 0.5050 - val_auc: 0.8515
# Epoch 29/30
# 39/39 [==============================] - 24s 624ms/step - loss: 0.2628 - auc: 0.9582 - val_loss: 0.5050 - val_auc: 0.8514
# Epoch 30/30
# 39/39 [==============================] - 24s 614ms/step - loss: 0.2727 - auc: 0.9553 - val_loss: 0.5058 - val_auc: 0.8512

# %%
# !tar -zcf model.tar.gz -C "/kaggle/working/" .
# Out:
# tar: .: file changed as we read it

# %%
from IPython.display import FileLink
FileLink(r'./model4.h5')
# Out:
# /kaggle/working/model4.h5
